# %% [markdown]
# <a href="https://colab.research.google.com/github/pazcalll/PCVK_Genap_2021/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv

from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# ys = 200 + np.random.randn(100)
# x = [x for x in range(len(ys))]

# plt.plot(x, ys, '-')
# plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

# plt.title("Sample Visualization")
# plt.show()

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_RGB2BGR)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('/n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8516d1a5d505> in <module>()
#       4
#       5 for url in urls:
# ----> 6   image = io.imread(url)
#       7   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#       8   image_2 = cv.cvtColor(image, cv.COLOR_RGB2BGR)
#
# NameError: name 'io' is not defined

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar 286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F7C8BAD0C50>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#making a horizontal line in the middle of the picture
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

cv.line(image_3, pt1=(200,0), pt2=(200,300), color=(255,255,255), thickness=1) # vertical
cv.line(image_3, pt1=(0,0), pt2=(lebar,tinggi), color=(255,255,255), thickness=1) # left to right
cv.line(image_3, pt1=(lebar,0), pt2=(0,tinggi), color=(255,255,255), thickness=1) # right to left

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# plt.imshow(image_3)
# plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7C8B8AD2E8>
